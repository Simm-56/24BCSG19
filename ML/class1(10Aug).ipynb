# %%
import pandas as pd
df = pd.read_csv(r"weather.csv")
print(df)
type(df)
# Out:
#           day  temperature  windspeed  humidity  event
# 0  01-01-2017           32          6        20   Rain
# 1  01-02-2017           35          7        30  Sunny
# 2  01-03-2017           28          2        45   Snow
# 3  01-04-2017           24          7        40   Snow
# 4  01-05-2017           32          4        35   Rain
# 5  01-06-2017           31          2        20  Sunny
# pandas.core.frame.DataFrame

# %%
#creating dataframe
weather_data = [['1/1/2017',32,6,20,'Rain'],
                ['1/2/2017',35,7,30,'Sunny'],
                ['1/3/2017',28,2,25,'Snow'],
                ['1/4/2017',24,7,45,'Snow'],
                ['1/5/2017',32,4,35,'Rain'],
                ['1/6/2017',31,2,20,'Sunny']]
df1= pd.DataFrame(weather_data,columns=['day','temperature','windspped','humidity','event'])
df1
# Out:
#         day  temperature  windspped  humidity  event
# 0  1/1/2017           32          6        20   Rain
# 1  1/2/2017           35          7        30  Sunny
# 2  1/3/2017           28          2        25   Snow
# 3  1/4/2017           24          7        45   Snow
# 4  1/5/2017           32          4        35   Rain
# 5  1/6/2017           31          2        20  Sunny

# %% [markdown]
# ## WORKING ON ROWS AND COLUMNS

# %%
print(df.shape) #to get the shape of the table/database
# Out:
# (6, 5)

# %%
#to print different columns there in the dataset
print(df.columns)
# Out:
# Index(['day ', 'temperature', 'windspeed', 'humidity', 'event'], dtype='object')

# %%
print(df.head)#to display first 5 columns
print(df.head(3))#to display first 3 columns
# Out:
# <bound method NDFrame.head of          day   temperature  windspeed  humidity  event
# 0  01-01-2017           32          6        20   Rain
# 1  01-02-2017           35          7        30  Sunny
# 2  01-03-2017           28          2        45   Snow
# 3  01-04-2017           24          7        40   Snow
# 4  01-05-2017           32          4        35   Rain
# 5  01-06-2017           31          2        20  Sunny>
#          day   temperature  windspeed  humidity  event
# 0  01-01-2017           32          6        20   Rain
# 1  01-02-2017           35          7        30  Sunny
# 2  01-03-2017           28          2        45   Snow

# %%
print(df.tail)#to display last 5 columns
print(df.tail(3))#to display last 3 columns
# Out:
# <bound method NDFrame.tail of          day   temperature  windspeed  humidity  event
# 0  01-01-2017           32          6        20   Rain
# 1  01-02-2017           35          7        30  Sunny
# 2  01-03-2017           28          2        45   Snow
# 3  01-04-2017           24          7        40   Snow
# 4  01-05-2017           32          4        35   Rain
# 5  01-06-2017           31          2        20  Sunny>
#          day   temperature  windspeed  humidity  event
# 3  01-04-2017           24          7        40   Snow
# 4  01-05-2017           32          4        35   Rain
# 5  01-06-2017           31          2        20  Sunny

# %%
print(df.sample(2))#to display random 2 samples
# Out:
#          day   temperature  windspeed  humidity  event
# 1  01-02-2017           35          7        30  Sunny
# 4  01-05-2017           32          4        35   Rain

# %%
#to print the data of a single column
df1.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df['day']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df1[['day','event']]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
#to print temperature column value
df.temperature.describe()
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: temperature, dtype: float64

# %%
df.info() #to get how many null values are there
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   humidity     6 non-null      int64
#  4   event        6 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 368.0+ bytes

# %%
df.iloc[2,4] #position based indexing
# Out:
# 'Snow'

# %%
df.loc[2,'event'] #lable based indexing
# Out:
# 'Snow'

# %%
df.loc[4,'temperature']
# Out:
# 32

# %% [markdown]
# ## OPERATIONS

# %%
#print the maximum temperature
print(max(df.temperature))
# Out:
# 35

# %%
df['temperature'].max() #another way to print max
# Out:
# 35

# %%
df['temperature'].min() #to print the minimum
# Out:
# 24

# %%
df['temperature'].std() #to print the std
# Out:
# 3.8297084310253524

# %%
#describe the columns temperature
df.temperature.describe()
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: temperature, dtype: float64

# %%
df.temperature == df.temperature.max()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: temperature, dtype: bool

# %%
df.temperature == df.temperature.min()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: temperature, dtype: bool

# %%
#select rows which has maximum temperature
df[df.temperature == df.temperature.max()]
# Out:
#           day  temperature  windspeed  humidity  event
# 1  01-02-2017           35          7        30  Sunny

# %%
#select rows which has minimum temperature
df[df.temperature == df.temperature.min()]
# Out:
#           day  temperature  windspeed  humidity event
# 3  01-04-2017           24          7        40  Snow

# %%
#select only day column which has maximum temperature
df.day[df.temperature == df.temperature.max()]
# Out:
# 1    01-02-2017
# Name: day, dtype: object

# %%
df.index #to show the staring and ending position stepwise
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day') #it will not modify the original dataframe
# Out:
#             temperature  windspeed  humidity  event
# day
# 01-01-2017           32          6        20   Rain
# 01-02-2017           35          7        30  Sunny
# 01-03-2017           28          2        45   Snow
# 01-04-2017           24          7        40   Snow
# 01-05-2017           32          4        35   Rain
# 01-06-2017           31          2        20  Sunny

# %%
df.set_index('day',inplace=True) #modifies the original datafram
df
# Out:
#             temperature  windspeed  humidity  event
# day
# 01-01-2017           32          6        20   Rain
# 01-02-2017           35          7        30  Sunny
# 01-03-2017           28          2        45   Snow
# 01-04-2017           24          7        40   Snow
# 01-05-2017           32          4        35   Rain
# 01-06-2017           31          2        20  Sunny

# %%
df.reset_index(inplace=True) #reset to the original dataframe again
df
# Out:
#           day  temperature  windspeed  humidity  event
# 0  01-01-2017           32          6        20   Rain
# 1  01-02-2017           35          7        30  Sunny
# 2  01-03-2017           28          2        45   Snow
# 3  01-04-2017           24          7        40   Snow
# 4  01-05-2017           32          4        35   Rain
# 5  01-06-2017           31          2        20  Sunny

# %%
#sort particular values under a particular name
df.sort_values(['windspeed'])
# Out:
#           day  temperature  windspeed  humidity  event
# 2  01-03-2017           28          2        45   Snow
# 5  01-06-2017           31          2        20  Sunny
# 4  01-05-2017           32          4        35   Rain
# 0  01-01-2017           32          6        20   Rain
# 1  01-02-2017           35          7        30  Sunny
# 3  01-04-2017           24          7        40   Snow
